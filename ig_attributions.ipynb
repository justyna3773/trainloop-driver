# %%
from attention_rl_temporal_spatial_detachable import load_model, run_ig_analysis
import numpy as np
import torch
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import display

feature_names =  [ "vmAllocatedRatio",
            "avgPUUtilization",
            "avgMemoryUtilization",
            "p90MemoryUtiCPUUtilization",
            "p90Clization",
            "waitingJobsRatioGlobal",
            "waitingJobsRatioRecent"]

# %%
import numpy as np
import torch
path = './models/14_07/attention_temporal_spatial/attention_temporal_spatial_MlpLstmPolicy_model'
model = load_model(path)
X = np.load(f'./models/14_07/attention_temporal_spatial/attention_temporal_spatial_MlpLstmPolicy_observations.npy')
X = torch.Tensor(X)
X.shape
predictions = []
for _ in X:
    predictions.append(model.predict(X[0])[0][0])
predictions = np.array(predictions)
# Out:
# Model loaded successfully

# %%
attr, fig = run_ig_analysis(model, X[5])
# Out:
# c:\Users\ultramarine\Desktop\ppo_magisterka\trainloop_driver_official\trainloop-driver\attention_rl_temporal_spatial_detachable.py:444: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   obs_tensor = th.tensor(observations, dtype=th.float32).to(device)

# %%
from attention_rl_automatic_detachable import run_ig_attribution, load_model
path = './models/14_07/attention/attention_MlpLstmPolicy_model.zip'
model = load_model(path, policy_type='PPO')
X = np.load(f'./models/14_07/attention/attention_MlpLstmPolicy_observations.npy')
X = torch.Tensor(X)
X.shape
predictions = []
for _ in X:
    predictions.append(model.predict(X[0])[0][0])
predictions = np.array(predictions)
# Out:
# Loaded PPO model from ./models/14_07/attention/attention_MlpLstmPolicy_model.zip

# %%
attr, fig = run_ig_attribution(model, X[5], feature_names=None, baseline_type="zero", n_steps=25)
# Out:
# c:\Users\ultramarine\Desktop\ppo_magisterka\trainloop_driver_official\trainloop-driver\attention_rl_automatic_detachable.py:705: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   obs_tensor = th.tensor(observations, dtype=th.float32).to(device)

# %%
from attention_rl_automatic_detachable import run_ig_attribution, load_model
path = './models/recurrentattention_MlpPolicy_model.zip'
model = load_model(path, policy_type='RecurrentPPO')
X = np.load(f'./models/14_07/recurrent_ppo_attention/recurrentattention_MlpPolicy_observations.npy')
X = torch.Tensor(X)
X.shape
predictions = []
for _ in X:
    predictions.append(model.predict(X[0])[0][0])
predictions = np.array(predictions)
# Out:
# Creating dummy environment for RecurrentPPO loading
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Loaded RecurrentPPO model from ./models/recurrentattention_MlpPolicy_model.zip

# %%
aatr, fig = run_ig_attribution(model, X[5], feature_names=feature_names, baseline_type="zero", n_steps=25)

# %%
from sparse_autoencoder import run_ig_attribution, load_model
path = './models/sparse_autoencoder_MlpPolicy_model.zip'
model = load_model(path)
X = np.load(f'./models/14_07/sparse_ae/sparse_autoencoder_MlpPolicy_observations.npy')
X = torch.Tensor(X)
X.shape
predictions = []
for _ in X:
    predictions.append(model.predict(X[0])[0][0])
predictions = np.array(predictions)
# Out:
# Creating temporary dummy environment for model loading
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Loaded model from ./models/sparse_autoencoder_MlpPolicy_model.zip
