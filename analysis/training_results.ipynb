# %%
sys.path.append(os.getcwd()+'/src/')
# %load_ext autoreload
# %autoreload 2
from plot import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
models = {
    'DQN': {'MlpPolicy', 'CnnPolicy'},
    'PPO': {'MlpPolicy', 'CnnPolicy'},
    'RecurrentPPO': {'MlpLstmPolicy', 'CnnLstmPolicy'},
}

# %% [markdown]
# ## REWARDS DURING TRAINING

# %%
for algo, policies in models.items():
    for policy in policies:
        try:
            plot_training_data(f"../best_model/{algo.lower()}/{policy}/training_data.csv", title=f'{algo} : {policy}', data_type='reward')
        except FileNotFoundError:
            plot_training_data(f"../best_model/{algo.lower()}/{policy}/best_model_rewards.csv", title=f'{algo} : {policy}', data_type='reward')

# %% [markdown]
# ## EPISODE LEN DURING TRAINING

# %%
for algo, policies in models.items():
    for policy in policies:
        try:
            plot_training_data(f"../best_model/{algo.lower()}/{policy}/training_data.csv", title=f'{algo} : {policy}', data_type='episode_len')
        except FileNotFoundError:
            plot_training_data(f"../best_model/{algo.lower()}/{policy}/best_model_rewards.csv", title=f'{algo} : {policy}', data_type='episode_len')
