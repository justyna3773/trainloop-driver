# %%
import torch
import numpy as np
import sys
import os

sys.path.append(os.getcwd()+'/../src/')
# %load_ext autoreload
# %autoreload 2

from attribute import *
from plot import *
from ppo_policy import *
from utils import *

# %%
from stable_baselines3 import PPO

# %%
BASE_PATH = '../../models/cnn/'
BASE_PATH2 = '../../initial_model'

# %%
model = PPO.load(os.path.join(BASE_PATH, f'PPO_CnnPolicy_model'))

X = np.load(os.path.join(BASE_PATH, f'PPO_CnnPolicy_observations.npy'))

X = torch.Tensor(X)
X.shape
# Out:
# torch.Size([286, 1, 1, 15, 7])

# %%
predictions = []
for _ in X:
    predictions.append(model.predict(X[0])[0][0])
predictions = np.array(predictions)

# %%
plot_action_histogram(predictions)

# %% [markdown]
# # Attributions

# %%
from ppo_policy import PPOPolicy
ppo_net = PPOPolicy(model.observation_space, model.action_space, model.lr_schedule, model)

# %%
x = torch.tensor(X[10])
ppo_net.forward(x)
# Out:
# c:\Users\ultramarine\.conda\envs\trainloop_py37\lib\site-packages\ipykernel_launcher.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """Entry point for launching an IPython kernel.
# tensor([[-1.0968]], grad_fn=<AddmmBackward0>)

# %%
# Random samples
N = 2000
idxs = np.random.choice(np.arange(X.shape[0]), size=N)
X_sample = X[idxs]
predictions_sample = predictions[idxs]

# Sequential samples
# i_start = 0
# i_stop = 500
# X_sample = X[i_start:i_stop]
# predictions_sample = predictions[i_start:i_stop]

ig_attributor = IGAttributor(net=ppo_net,
                            policy='cnn',
                            agent='ppo',
                            data=X_sample,
                            predictions=predictions_sample)

# %% [markdown]
# # Mean Attributions

# %%
mean_attributions_per_action = ig_attributor.get_mean_attributions()

# %%
plot_mean_attributions(mean_attributions=mean_attributions_per_action[0], policy='cnn', abs=True)

# %%
plot_mean_attributions(mean_attributions=mean_attributions_per_action[0], policy='cnn')

# %% [markdown]
# # Attributions for examples

# %%
ig_attributor.explain_example(4)

# %%
ig_attributor.explain_example(300)

# %%
ig_attributor.explain_example(330)

# %%
action_observation_map = get_action_observation_map(predictions)
# Out:
# Observation count for each action:
# {'ADD_LARGE_VM': 286,
#  'ADD_MEDIUM_VM': 0,
#  'ADD_SMALL_VM': 0,
#  'NOTHING': 0,
#  'REMOVE_LARGE_VM': 0,
#  'REMOVE_MEDIUM_VM': 0,
#  'REMOVE_SMALL_VM': 0}

# %%
idx = action_observation_map['REMOVE_SMALL_VM'].squeeze(1)[:500]

# %%
ig_attributor = IGAttributor(net=ppo_net,
                            policy='cnn',
                            agent='ppo',
                            data=X[idx],
                            predictions=predictions[idx])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27676\2916490944.py in <module>
#       3                             agent='ppo',
#       4                             data=X[idx],
# ----> 5                             predictions=predictions[idx])
#
# c:\Users\ultramarine\Desktop\ppo_magisterka\trainloop_driver\trainloop-driver\analysis\initial_training/../src\attribute.py in __init__(self, net, policy, agent, data, predictions, method, baselines, target, forward_args, n_steps, attributions_len, action_names, feature_names)
#      37         self.data = data
#      38         self.predictions = predictions
# ---> 39         self._calculate_attributions_per_action()
#      40
#      41     def get_mean_attributions(self) -> list:
#
# c:\Users\ultramarine\Desktop\ppo_magisterka\trainloop_driver\trainloop-driver\analysis\initial_training/../src\attribute.py in _calculate_attributions_per_action(self)
#     134                                                         baselines=self.baselines,
#     135                                                         return_convergence_delta=True,
# --> 136                                                         additional_forward_args=self.forward_args)
#     137             else:
#     138                 attributions, delta = self.ig.attribute(data,
#
# c:\Users\ultramarine\.conda\envs\trainloop_py37\lib\site-packages\captum\log\__init__.py in wrapper(*args, **kwargs)
#      40             @wraps(func)
#      41             def wrapper(*args, **kwargs):
# ---> 42                 return func(*args, **kwargs)
#      43
#      44             return wrapper
#
# c:\Users\ultramarine\.conda\envs\trainloop_py37\lib\site-packages\captum\attr\_core\integrated_gradients.py in attribute(self, inputs, baselines, target, additional_forward_args, n_steps, method, internal_batch_size, return_convergence_delta)
#     290                 additional_forward_args=additional_forward_args,
#     291                 n_steps=n_steps,
# --> 292                 method=method,
#     293             )
#     294
#
# c:\Users\ultramarine\.conda\envs\trainloop_py37\lib\site-packages\captum\attr\_core\integrated_gradients.py in _attribute(self, inputs, baselines, target, additional_forward_args, n_steps, method, step_sizes_and_alphas)
#     353             inputs=scaled_features_tpl,
#     354             target_ind=expanded_target,
# --> 355             additional_forward_args=input_additional_args,
#     356         )
#     357
#
# c:\Users\ultramarine\.conda\envs\trainloop_py37\lib\site-packages\captum\_utils\gradient.py in compute_gradients(forward_fn, inputs, target_ind, additional_forward_args)
#     111         # runs forward pass
#     112         outputs = _run_forward(forward_fn, inputs, target_ind, additional_forward_args)
# --> 113         assert outputs[0].numel() == 1, (
#     114             "Target not provided when necessary, cannot"
#     115             " take gradient with respect to multiple outputs."
#
# IndexError: index 0 is out of bounds for dimension 0 with size 0

# %%
ig_attributor.explain_example(idx=1)
