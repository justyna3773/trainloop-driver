# %%
import torch
import numpy as np
import sys
import os
import matplotlib.pyplot as plt

sys.path.append(os.getcwd()+'/src/')
# %load_ext autoreload
# %autoreload 2

from utils import *


plt.style.use('seaborn-deep')

# %%
models = {
    'Attention_gAWRL': parse_tensorboard(path='../output_malota/gawrl_old/PPO_26', scalars=['rollout/ep_rew_mean']),
    'Attention_TrXL': parse_tensorboard(path='../output_malota/PPO_67', scalars=['rollout/ep_rew_mean']),
    'SPCA': parse_tensorboard(path='../output_malota/PPO_72', scalars=['rollout/ep_rew_mean']),
    'PPO baseline': parse_tensorboard(path='../output_malota/PPO_87', scalars=['rollout/ep_rew_mean']),
    'RecurrentPPO baseline': parse_tensorboard(path='../output_malota/RecurrentPPO_6', scalars=['rollout/ep_rew_mean'])
}

# %%
models = {
    #'Model z metrykami wybranymi przez "Attention"': parse_tensorboard(path='../output_malota/PPO_94', scalars=['rollout/ep_rew_mean']),
    #'Model z metrykami wybranymi przez SPCA': parse_tensorboard(path='../output_malota/PPO_95', scalars=['rollout/ep_rew_mean']),
    'PPO baseline (wszystkie metryki)': parse_tensorboard(path='../output_malota/PPO_87', scalars=['rollout/ep_rew_mean']),
    'PPO baseline z metrykami zbiór 1': parse_tensorboard(path='../output_malota/PPO_98', scalars=['rollout/ep_rew_mean']),
    'PPO baseline z metrykami zbiór 2': parse_tensorboard(path='../output_malota/RecurrentPPO_91', scalars=['rollout/ep_rew_mean']),
    'PPO baseline z metrykami zbiór 3 (mało informacyjne metryki)': parse_tensorboard(path='../output_malota/PPO_96', scalars=['rollout/ep_rew_mean']),
}

# %%
plt.figure(figsize=(12, 5))
for model, data in models.items():
    plt.plot(data['rollout/ep_rew_mean']['step'], data['rollout/ep_rew_mean']['value'])

plt.legend(list(models.keys()))
plt.xlabel("Kroki")
plt.ylabel("Średnia nagroda z epizodu")
plt.title("Średnia nagroda za epizod w zależności od kroków treningu")
# Out:
# Text(0.5, 1.0, 'Średnia nagroda za epizod w zależności od kroków treningu')

# %%
models = {
    'Model z modułem SPCA': parse_tensorboard(path='../output_malota/PPO_104', scalars=['rollout/ep_rew_mean']),
    'Model z modułem "Attention"': parse_tensorboard(path='../output_malota/gawrl_old/PPO_28', scalars=['rollout/ep_rew_mean']),
    'PPO baseline': parse_tensorboard(path='../output_malota/PPO_99', scalars=['rollout/ep_rew_mean'])
}

# %%
plt.figure(figsize=(12, 5))
for model, data in models.items():
    plt.plot(data['rollout/ep_rew_mean']['step'], data['rollout/ep_rew_mean']['value'])

plt.legend(list(models.keys()))
plt.xlabel("Kroki")
plt.ylabel("Średnia nagroda z epizodu")
plt.title("Średnia nagroda za epizod w zależności od kroków treningu")
# Out:
# Text(0.5, 1.0, 'Średnia nagroda za epizod w zależności od kroków treningu')

# %%
models = {
    'Model wytrenowany na metrykach wybranych przez "Attention"': parse_tensorboard(path='../output_malota/PPO_105', scalars=['rollout/ep_rew_mean']),
    'Model wytrenowany na metrykach wybranych przez SPCA': parse_tensorboard(path='../output_malota/PPO_106', scalars=['rollout/ep_rew_mean']),
    'PPO-CNN baseline': parse_tensorboard(path='../output_malota/PPO_107', scalars=['rollout/ep_rew_mean'])
}
plt.figure(figsize=(12, 5))
for model, data in models.items():
    plt.plot(data['rollout/ep_rew_mean']['step'], data['rollout/ep_rew_mean']['value'])

plt.legend(list(models.keys()))
plt.xlabel("Kroki")
plt.ylabel("Średnia nagroda z epizodu")
plt.title("Średnia nagroda za epizod w zależności od kroków treningu - polityki CNN")
# Out:
# Text(0.5, 1.0, 'Średnia nagroda za epizod w zależności od kroków treningu - polityki CNN')

# %%
# df = parse_tensorboard(path='../output_models_initial/recurrentppo/MlpLstmPolicy/RecurrentPPO_1', scalars=['rollout/ep_rew_mean'])

models = {
    'DQN': {'MlpPolicy', 'CnnPolicy'},
    'PPO': {'MlpPolicy', 'CnnPolicy'},
    'RecurrentPPO': {'MlpLstmPolicy', 'CnnLstmPolicy'},
}


for algo, policies in models.items():
    for policy in policies:
        
        
df = parse_tensorboard(path='../output_models_initial/dqn/MlpPolicy/DQN_2', scalars=['rollout/ep_rew_mean'])
df = parse_tensorboard(path='../output_models_initial/dqn/MlpPolicy/DQN_2', scalars=['rollout/ep_rew_mean'])

# %%
# OLD
models = {
    'DQN_MlpPolicy': parse_tensorboard(path='../output_models_initial/dqn/MlpPolicy/DQN_5', scalars=['rollout/ep_rew_mean']),
    'DQN_CnnPolicy': parse_tensorboard(path='../output_models_initial/dqn/CnnPolicy/DQN_3', scalars=['rollout/ep_rew_mean']),
    'PPO_MlpPolicy': parse_tensorboard(path='../output_models_initial/ppo/MlpPolicy/PPO_10', scalars=['rollout/ep_rew_mean']),
    'PPO_CnnPolicy': parse_tensorboard(path='../output_models_initial/ppo/CnnPolicy/PPO_9', scalars=['rollout/ep_rew_mean']),
    'RecurrentPPO_MlpLstmPolicy': parse_tensorboard(path='../output_models_initial/recurrentppo/MlpLstmPolicy/RecurrentPPO_22', scalars=['rollout/ep_rew_mean']),
    'RecurrentPPO_CnnLstmPolicy': parse_tensorboard(path='../output_models_initial/recurrentppo/CnnLstmPolicy/RecurrentPPO_8', scalars=['rollout/ep_rew_mean']),
}

# %%
models = {
    'DQN_MlpPolicy': parse_tensorboard(path='../output_models_initial/dqn/MlpPolicy/DQN_6', scalars=['rollout/ep_rew_mean']),
    'DQN_CnnPolicy': parse_tensorboard(path='../output_models_initial/dqn/CnnPolicy/DQN_5', scalars=['rollout/ep_rew_mean']),
    'PPO_MlpPolicy': parse_tensorboard(path='../output_models_initial/ppo/MlpPolicy/PPO_10', scalars=['rollout/ep_rew_mean']),
    'PPO_CnnPolicy': parse_tensorboard(path='../output_models_initial/ppo/CnnPolicy/PPO_9', scalars=['rollout/ep_rew_mean']),
    'RecurrentPPO_MlpLstmPolicy': parse_tensorboard(path='../output_models_initial/recurrentppo/MlpLstmPolicy/RecurrentPPO_22', scalars=['rollout/ep_rew_mean']),
    'RecurrentPPO_CnnLstmPolicy': parse_tensorboard(path='../output_models_initial/recurrentppo/CnnLstmPolicy/RecurrentPPO_8', scalars=['rollout/ep_rew_mean']),
}

# %%
plt.figure(figsize=(12, 5))
for model, data in models.items():
    plt.plot(data['rollout/ep_rew_mean']['step'], data['rollout/ep_rew_mean']['value'])

plt.legend(list(models.keys()))
plt.xlabel("Steps")
plt.ylabel("Mean episode reward")
plt.title("Mean episode reward during training")
# Out:
# Text(0.5, 1.0, 'Mean episode reward during training')

# %%
data['rollout/ep_rew_mean']['step'][:-10].shape[0]
# Out:
# (23,)

# %%
plt.figure(figsize=(12, 5))
for model, data in models.items():
    plt.plot(data['rollout/ep_rew_mean']['step'][:-4], data['rollout/ep_rew_mean']['value'][:-4])

plt.legend(list(models.keys()))
plt.xlabel("Steps")
plt.ylabel("Mean episode reward")
plt.title("Mean episode reward during training")
# Out:
# Text(0.5, 1.0, 'Mean episode reward during training')

# %%
ppo_models = {
    'PPO_MlpPolicy': parse_tensorboard(path='../output_models_initial/ppo/MlpPolicy/PPO_10', scalars=['rollout/ep_rew_mean']),
    'PPO_CnnPolicy': parse_tensorboard(path='../output_models_initial/ppo/CnnPolicy/PPO_9', scalars=['rollout/ep_rew_mean']),
    'RecurrentPPO_MlpLstmPolicy': parse_tensorboard(path='../output_models_initial/recurrentppo/MlpLstmPolicy/RecurrentPPO_22', scalars=['rollout/ep_rew_mean']),
    'RecurrentPPO_CnnLstmPolicy': parse_tensorboard(path='../output_models_initial/recurrentppo/CnnLstmPolicy/RecurrentPPO_8', scalars=['rollout/ep_rew_mean']),
}

# %%
plt.figure(figsize=(11, 4))
for model, data in ppo_models.items():
    if model == 'RecurrentPPO_MlpLstmPolicy':
        plt.plot(data['rollout/ep_rew_mean']['step'][:-4], data['rollout/ep_rew_mean']['value'][:-4])
    else:
        plt.plot(data['rollout/ep_rew_mean']['step'], data['rollout/ep_rew_mean']['value'])

plt.legend([algo for algo in list(models.keys()) if 'PPO' in algo])
plt.xlabel("Steps")
plt.ylabel("Mean episode reward")
plt.title("Mean episode reward during training of the PPO agents")
# Out:
# Text(0.5, 1.0, 'Mean episode reward during training of the PPO agents')

# %%
plt.plot(df['rollout/ep_rew_mean']['step'], df['rollout/ep_rew_mean']['value'])

# %%
df['rollout/ep_rew_mean']
# Out:
#       wall_time   step       value
# 0  1.656772e+09  12288 -167.761536
# 1  1.656772e+09  24576 -216.462067
# 2  1.656773e+09  36864 -283.451660
# 3  1.656773e+09  49152 -390.873291
# 4  1.656773e+09  61440 -478.232300
# 5  1.656774e+09  73728 -572.113342
# 6  1.656774e+09  86016 -659.244934

# %%
plt.figure(figsize=(15, 6))
plt.plot(rewards)
plt.legend(rewards.columns)
plt.show()

# %%
X = np.load(f'../initial_model/best_models/recurrentppo/MlpLstmPolicy/observations.npy')

# %%
X = np.load(f'../initial_model/best_models/ppo/CnnPolicy/observations.npy')

# %%
X.shape
# Out:
# (3618, 1, 1, 15, 7)

# %%
X.shape
# Out:
# (3617, 1, 1, 15, 7)

# %%
X.shape[-2]
# Out:
# 1
